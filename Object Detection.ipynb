# %% [markdown]
# # Object Detection Engine in 30mins

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import torch
from torchvision.utils import draw_bounding_boxes
from torchvision.io import read_image
from pathlib import Path

# %%
model = torch.hub.load(r"C:\Users\LakshmipathyGanesh/.cache\torch\hub\ultralytics_yolov5_master", 'yolov5s', source='local', pretrained=True)
#model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in C:\Users\LakshmipathyGanesh/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2021-10-25 torch 1.10.0+cpu CPU
#
# Fusing layers...
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ..\aten\src\ATen\native\TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# ## Detect Objects from Image

# %%
imgs = ['https://ultralytics.com/images/zidane.jpg']

# %%
results = model(imgs)
# Out:
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')

# %%
results.print()
# Out:
# image 1/1: 720x1280 2 persons, 1 tie
# Speed: 2434.1ms pre-process, 489.6ms inference, 2.8ms NMS per image at shape (1, 3, 384, 640)

# %%
results.save()
# Out:
# Saved 1 image to runs\detect\exp

# %%
results.xyxy[0]
df_result = results.pandas().xyxy[0]

# %%
df_result
# Out:
#          xmin        ymin         xmax        ymax  confidence  class    name
# 0  751.976257   45.534912  1148.378174  716.009094    0.875967      0  person
# 1  100.098572  201.318329  1001.132141  718.732788    0.572351      0  person
# 2  438.377991  422.251465   509.991943  720.000000    0.525458     27     tie

# %% [markdown]
# ## Real-time object detection

# %%
import cv2

# %%
cap = cv2.VideoCapture(0)
while True:
    ret, image_np = cap.read()
    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image_np, axis=0)
    # Actual detection.
    results = model(image_np)
    df_result = results.pandas().xyxy[0]
    dict_result = df_result.to_dict()
    scores = list(dict_result["confidence"].values())
    labels = list(dict_result["name"].values())
    list_boxes = list()
    for dict_item in df_result.to_dict('records'):
        list_boxes.append(list(dict_item.values())[:4])
    count = 0
    for xmin, ymin, xmax, ymax in list_boxes:
        image_np = cv2.rectangle(image_np, pt1=(int(xmin),int(ymin)), pt2=(int(xmax),int(ymax)), color=(255,0, 0), thickness=2);
        cv2.putText(image_np, f"{labels[count]}: {round(scores[count], 2)}", (int(xmin), int(ymin)-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
        count = count + 1
        
    cv2.imshow('Object Detector', image_np);
    
#     cv2.imshow('object detection', cv2.resize(image_np, (800,600)))
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\LAKSHM~1\AppData\Local\Temp/ipykernel_25860/174762478.py in <module>
#       5     image_np_expanded = np.expand_dims(image_np, axis=0)
#       6     # Actual detection.
# ----> 7     results = model(image_np)
#       8     df_result = results.pandas().xyxy[0]
#       9     dict_result = df_result.to_dict()
#
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py in forward(self, imgs, size, augment, profile)
#     345         with amp.autocast(enabled=p.device.type != 'cpu'):
#     346             # Inference
# --> 347             y = self.model(x, augment, profile)[0]  # forward
#     348             t.append(time_sync())
#     349
#
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.cache\torch\hub\ultralytics_yolov5_master\models\yolo.py in forward(self, x, augment, profile, visualize)
#     124         if augment:
#     125             return self._forward_augment(x)  # augmented inference, None
# --> 126         return self._forward_once(x, profile, visualize)  # single-scale inference, train
#     127
#     128     def _forward_augment(self, x):
#
# ~/.cache\torch\hub\ultralytics_yolov5_master\models\yolo.py in _forward_once(self, x, profile, visualize)
#     147             if profile:
#     148                 self._profile_one_layer(m, x, dt)
# --> 149             x = m(x)  # run
#     150             y.append(x if m.i in self.save else None)  # save output
#     151             if visualize:
#
# c:\users\lakshmipathyganesh\.conda\envs\scoring3.7.3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py in forward(self, x)
#     193             y1 = self.m(x)
#     194             y2 = self.m(y1)
# --> 195             return self.cv2(torch.cat([x, y1, y2, self.m(y2)], 1))
#     196
#     197
#
# KeyboardInterrupt:

# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ ---------------------
# absl-py                  0.15.0
# argcomplete              1.12.3
# argon2-cffi              21.1.0
# attrs                    21.2.0
# backcall                 0.2.0
# beautifulsoup4           4.9.1
# bleach                   4.1.0
# blis                     0.7.4
# bs4                      0.0.1
# cachetools               4.1.1
# certifi                  2020.6.20
# cffi                     1.14.3
# chardet                  3.0.4
# charset-normalizer       2.0.7
# click                    7.1.2
# cloudpickle              1.6.0
# colorama                 0.4.4
# cycler                   0.10.0
# cymem                    2.0.5
# dask                     2021.7.2
# debugpy                  1.5.1
# decorator                5.1.0
# defusedxml               0.7.1
# distributed              2021.7.2
# emoji                    0.6.0
# entrypoints              0.3
# fasttext                 0.9.2
# flatten-json             0.1.7
# google-api-core          1.22.2
# google-auth              1.21.2
# google-auth-oauthlib     0.4.6
# google-cloud-core        1.4.1
# google-cloud-storage     1.31.0
# google-crc32c            1.0.0
# google-resumable-media   1.0.0
# googleapis-common-protos 1.52.0
# grpcio                   1.41.0
# html5lib                 1.1
# idna                     2.10
# importlib-metadata       4.8.1
# ipykernel                6.4.2
# ipython                  7.28.0
# ipython-genutils         0.2.0
# ipywidgets               7.6.5
# jedi                     0.18.0
# Jinja2                   3.0.2
# joblib                   0.16.0
# jsonschema               4.1.2
# jupyter                  1.0.0
# jupyter-client           7.0.6
# jupyter-console          6.4.0
# jupyter-core             4.8.1
# jupyterlab-pygments      0.1.2
# jupyterlab-widgets       1.0.2
# keybert                  0.3.0
# kiwisolver               1.3.2
# Markdown                 3.3.4
# MarkupSafe               2.0.1
# matplotlib               3.4.3
# matplotlib-inline        0.1.3
# mistune                  0.8.4
# modin                    0.10.1
# murmurhash               1.0.5
# nbclient                 0.5.4
# nbconvert                6.2.0
# nbformat                 5.1.3
# nest-asyncio             1.5.1
# nltk                     3.6.3
# notebook                 6.4.5
# numpy                    1.21.0
# oauthlib                 3.1.1
# opencv-python            4.5.4.58
# packaging                21.0
# pandas                   1.3.0
# pandocfilters            1.5.0
# parso                    0.8.2
# pathy                    0.6.0
# pickleshare              0.7.5
# Pillow                   8.4.0
# pip                      20.2.2
# preshed                  3.0.5
# prometheus-client        0.11.0
# prompt-toolkit           3.0.21
# protobuf                 3.13.0
# pyasn1                   0.4.8
# pyasn1-modules           0.2.8
# pybind11                 2.5.0
# pycparser                2.20
# pydantic                 1.7.4
# Pygments                 2.10.0
# pyparsing                3.0.1
# pyrsistent               0.18.0
# python-dateutil          2.8.1
# pytz                     2020.1
# pywin32                  302
# pywinpty                 1.1.4
# PyYAML                   6.0
# pyzmq                    22.3.0
# qtconsole                5.1.1
# QtPy                     1.11.2
# rake-nltk                1.0.6
# regex                    2020.7.14
# requests                 2.26.0
# requests-oauthlib        1.3.0
# rsa                      4.6
# scipy                    1.7.1
# seaborn                  0.11.2
# Send2Trash               1.8.0
# sentence-transformers    2.0.0
# setuptools               49.6.0.post20200814
# six                      1.15.0
# smart-open               5.1.0
# soupsieve                2.0.1
# spacy                    3.0.6
# spacy-legacy             3.0.6
# tensorboard              2.7.0
# tensorboard-data-server  0.6.1
# tensorboard-plugin-wit   1.8.0
# terminado                0.12.1
# testpath                 0.5.0
# thinc                    8.0.6
# thop                     0.0.31.post2005241907
# torch                    1.10.0
# torchvision              0.11.1
# tornado                  6.1
# tqdm                     4.49.0
# traitlets                5.1.1
# typer                    0.3.2
# typing-extensions        3.10.0.2
# urllib3                  1.25.10
# wasabi                   0.8.2
# wcwidth                  0.2.5
# webencodings             0.5.1
# Werkzeug                 2.0.2
# wheel                    0.35.1
# widgetsnbextension       3.5.1
# wincertstore             0.2
# wordwise                 0.0.3
# zipp                     3.6.0
